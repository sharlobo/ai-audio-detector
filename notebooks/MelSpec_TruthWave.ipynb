# %% [markdown]
# # Mel Spectrogram

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in ./wavenv/lib/python3.9/site-packages (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in ./wavenv/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in ./wavenv/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./wavenv/lib/python3.9/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./wavenv/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in ./wavenv/lib/python3.9/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in ./wavenv/lib/python3.9/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in ./wavenv/lib/python3.9/site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./wavenv/lib/python3.9/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in ./wavenv/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./wavenv/lib/python3.9/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in ./wavenv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in ./wavenv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#libraries 
#basic imports
import os
import numpy as np
from pathlib import Path

# PyTorch setup
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader, random_split

# metrics
from sklearn.metrics import classification_report

import librosa
import matplotlib.pyplot as plt

# %% [markdown]
# ## Mel Spectrogram Feature Extraction Function
#
# *  Taking an audio file path and getting a fixed size mel spectrogram
# * visual representation of the sound frequencies over time
# * meant to mimic how humans perceive sound

# %%
# define
def extract_mel_spectrogram(file_path, n_mels=128, max_len=128):
    try:
        y, sr = librosa.load(file_path, sr=16000)  # resample to 16kHz
        S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=n_mels)
        S_dB = librosa.power_to_db(S, ref=np.max)

        # padding or truncating to fixed length
        if S_dB.shape[1] < max_len:
            pad_width = max_len - S_dB.shape[1]
            S_dB = np.pad(S_dB, ((0, 0), (0, pad_width)), mode='constant')
        else:
            S_dB = S_dB[:, :max_len]
            
# processed spectrogram
        return S_dB
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        return None

# %%
# directory setup 
# set paths for mel spectrogram features
real_mel_dir = Path("mel_features/real")
fake_mel_dir = Path("mel_features/fake")

# creating directories if they don't exist
real_mel_dir.mkdir(parents=True, exist_ok=True)
fake_mel_dir.mkdir(parents=True, exist_ok=True)

# path for raw audio files
real_base = Path("fake_audio/REAL")
fake_base = Path("fake_audio/FAKE")

# %% [markdown]
# ## Extraction and Save
# * converting raw files into mel spectrogram and saving as .npy files

# %%
# loop through all folders
def process_and_save(base_path, out_path):
    for folder in base_path.iterdir():
        if folder.is_dir():
            for wav_file in folder.glob("*.wav"):
                save_name = f"{folder.name}_{wav_file.name.replace('.wav', '.npy')}"
                save_path = out_path / save_name

                # skip if already processed - skip logic! 
                if save_path.exists():
                    print(f"Skipping already processed: {save_path}")
                    continue

                features = extract_mel_spectrogram(str(wav_file))
                if features is not None:
                    np.save(save_path, features)
                    print(f"Saved features to: {save_path}")

# %%
# calling function 
process_and_save(real_base, real_mel_dir)
process_and_save(fake_base, fake_mel_dir)
# Out:
# Skipping already processed: mel_features/real/obama-original_segment_5660.npy
# Skipping already processed: mel_features/real/obama-original_segment_5667.npy
# Skipping already processed: mel_features/real/obama-original_segment_5615.npy
# Skipping already processed: mel_features/real/obama-original_segment_5669.npy
# Skipping already processed: mel_features/real/obama-original_segment_5731.npy
# Skipping already processed: mel_features/real/obama-original_segment_5703.npy
# Skipping already processed: mel_features/real/obama-original_segment_5627.npy
# Skipping already processed: mel_features/real/obama-original_segment_5620.npy
# Skipping already processed: mel_features/real/obama-original_segment_5704.npy
# Skipping already processed: mel_features/real/obama-original_segment_5683.npy
# Skipping already processed: mel_features/real/obama-original_segment_5652.npy
# Skipping already processed: mel_features/real/obama-original_segment_5684.npy
# Skipping already processed: mel_features/real/obama-original_segment_5655.npy
npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4757.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4725.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4722.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4707.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4700.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4689.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4658.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4687.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4656.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4709.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4680.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4651.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4740.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4664.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4663.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4747.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4735.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4749.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4732.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4723.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4724.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4758.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4672.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4756.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4751.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4675.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4640.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4691.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4718.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4647.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4696.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4649.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4698.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4711.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4716.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4727.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4678.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4720.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4752.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4676.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4671.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4729.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4755.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4644.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4695.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4643.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4692.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4715.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4712.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4703.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4704.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4683.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4652.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4684.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4655.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4738.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4660.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4744.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4743.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4667.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4731.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4669.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4736.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4713.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4714.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4642.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4693.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4645.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4694.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4639.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4670.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4728.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4754.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4753.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4677.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4679.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4721.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4726.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4737.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4730.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4668.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4742.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4666.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4739.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4661.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4745.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4685.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4654.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4682.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4653.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4705.npy
# Skipping already processed: mel_features/fake/Obama-to-Trump_segment_4702.npy

# %% [markdown]
# ## Truncating / Padding Features
#
# * function so all features have the same shape
# input: a 2d array with shape
# output: a 2d array padded or truncated
#
# * mel spectrogram can have slightly different time durations, resulting in inconsistent shapes. Function standardizes them.

# %%
# all features have same shape - for NN uniform input size
def pad_or_truncate(feature, target_shape=(128, 256)):
    h, w = feature.shape
    target_h, target_w = target_shape

    # truncate if too big
    feature = feature[:target_h, :target_w]

    # pad if too small
    pad_h = target_h - feature.shape[0]
    pad_w = target_w - feature.shape[1]

    return np.pad(feature, ((0, pad_h), (0, pad_w)), mode='constant')

# %%
# loading and labeling features 
# apply padding/ truncation to .npy files
X = []
y = []

# loading/ processing files
for file in Path("mel_features/real").glob("*.npy"):
    mel = np.load(file)
    X.append(pad_or_truncate(mel))
    y.append(0)

for file in Path("mel_features/fake").glob("*.npy"):
    mel = np.load(file)
    X.append(pad_or_truncate(mel))
    y.append(1)

# converting into numpy arrays 
X = np.array(X)
y = np.array(y)

print("Shape:", X.shape, y.shape)
# Out:
# Shape: (3725, 128, 256) (3725,)

# %%
#flattening mel spectrogram - 1D vector
X = X.reshape(X.shape[0], -1)
print("Flattened shape:", X.shape)
# Out:
# Flattened shape: (3725, 32768)

# %%
# splitting dataset for training and testing 
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

print("Train shape:", X_train.shape, "Test shape:", X_test.shape)
# Out:
# Train shape: (2980, 32768) Test shape: (745, 32768)

# %%
## Defining and Training on Mel Spectrogram

# %%
# import libraries 
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import classification_report

# convert data to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1)

# create a dataloader
# batches training data and shuffles to improve generalization
train_loader = DataLoader(TensorDataset(X_train_tensor, y_train_tensor), batch_size=32, shuffle=True)

# model def: MLP model
class MLP(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 512),
            nn.ReLU(), # ReLU
            nn.Dropout(0.3),
            nn.Linear(512, 128),
            nn.ReLU(),
            nn.Linear(128, 1),
            nn.Sigmoid() # single neuron with sigmoid function
        )

    def forward(self, x):
        return self.net(x)

model = MLP(X_train.shape[1])
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# training loop
for epoch in range(100):
    model.train()
    for xb, yb in train_loader:
        preds = model(xb)
        loss = criterion(preds, yb)
        optimizer.zero_grad()
        loss.backward() # binary cross entropy
        optimizer.step() # adam to adjust weight during backprop
    print(f"Epoch {epoch+1} Loss: {loss.item():.4f}")
# Out:
# Epoch 1 Loss: 1.5813
# Epoch 2 Loss: 0.1814
# Epoch 3 Loss: 0.0003
# Epoch 4 Loss: 0.0088
# Epoch 5 Loss: 0.0149
# Epoch 6 Loss: 0.0401
# Epoch 7 Loss: 0.1454
# Epoch 8 Loss: 0.0023
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 44
#      42     optimizer.zero_grad()
#      43     loss.backward()
# ---> 44     optimizer.step()
#      45 print(f"Epoch {epoch+1} Loss: {loss.item():.4f}")
#
# File ~/wavenv/lib/python3.9/site-packages/torch/optim/optimizer.py:391, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     386         else:
#     387             raise RuntimeError(
#     388                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     389             )
# --> 391 out = func(*args, **kwargs)
#     392 self._optimizer_step_code()
#     394 # call optimizer step post hooks
#
# File ~/wavenv/lib/python3.9/site-packages/torch/optim/optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File ~/wavenv/lib/python3.9/site-packages/torch/optim/adam.py:168, in Adam.step(self, closure)
#     157     beta1, beta2 = group['betas']
#     159     has_complex = self._init_group(
#     160         group,
#     161         params_with_grad,
#    (...)
#     165         max_exp_avg_sqs,
#     166         state_steps)
# --> 168     adam(
#     169         params_with_grad,
#     170         grads,
#     171         exp_avgs,
#     172         exp_avg_sqs,
#     173         max_exp_avg_sqs,
#     174         state_steps,
#     175         amsgrad=group['amsgrad'],
#     176         has_complex=has_complex,
#     177         beta1=beta1,
#     178         beta2=beta2,
#     179         lr=group['lr'],
#     180         weight_decay=group['weight_decay'],
#     181         eps=group['eps'],
#     182         maximize=group['maximize'],
#     183         foreach=group['foreach'],
#     184         capturable=group['capturable'],
#     185         differentiable=group['differentiable'],
#     186         fused=group['fused'],
#     187         grad_scale=getattr(self, "grad_scale", None),
#     188         found_inf=getattr(self, "found_inf", None),
#     189     )
#     191 return loss
#
# File ~/wavenv/lib/python3.9/site-packages/torch/optim/adam.py:318, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     315 else:
#     316     func = _single_tensor_adam
# --> 318 func(params,
#     319      grads,
#     320      exp_avgs,
#     321      exp_avg_sqs,
#     322      max_exp_avg_sqs,
#     323      state_steps,
#     324      amsgrad=amsgrad,
#     325      has_complex=has_complex,
#     326      beta1=beta1,
#     327      beta2=beta2,
#     328      lr=lr,
#     329      weight_decay=weight_decay,
#     330      eps=eps,
#     331      maximize=maximize,
#     332      capturable=capturable,
#     333      differentiable=differentiable,
#     334      grad_scale=grad_scale,
#     335      found_inf=found_inf)
#
# File ~/wavenv/lib/python3.9/site-packages/torch/optim/adam.py:443, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     440     else:
#     441         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
# --> 443     param.addcdiv_(exp_avg, denom, value=-step_size)
#     445 # Lastly, switch back to complex view
#     446 if amsgrad and torch.is_complex(params[i]):
#
# KeyboardInterrupt:

# %%
# evaluation
model.eval()
with torch.no_grad():
    test_preds = model(X_test_tensor)
    test_preds = torch.round(test_preds).squeeze() # values >= are classified as 1 
    # values < 0.5 are classified as real 

from sklearn.metrics import classification_report
print(classification_report(y_test, test_preds.numpy()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.38      0.50       151
#            1       0.86      0.97      0.91       594
#
#     accuracy                           0.85       745
#    macro avg       0.80      0.67      0.70       745
# weighted avg       0.84      0.85      0.83       745

# %%
# saving model 
torch.save(model.state_dict(), "mlp_melspec_model.pth")

# %%
# saving testing
np.save("y_test.npy", y_test)
